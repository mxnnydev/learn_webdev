# %% [markdown]
# # CSS Topics to Learn
#
# ---
#
# ### 🔹 1. **Selectors & Syntax 🎉**
#
# - `class`, `id`, element selectors
# - Combining selectors (`div > p`, `ul li`)
# - universal selector (rarely used, but good to know)
#
# ### 🔹 2. **Box Model**
#
# - `margin`, `border`, `padding`, `content`
# - Understand spacing between and inside elements
#
# ### 🔹 3. **Display & Positioning**
#
# - `display: block / inline / inline-block / flex / grid`
# - `position: static / relative / absolute / fixed / sticky`
#
# ### 🔹 4. **Flexbox (Master This 💯)**
#
# - `display: flex`, `justify-content`, `align-items`, `gap`
# - `flex-direction`, `flex-wrap`
# - Centering elements (horizontally + vertically)
#
# ### 🔹 5. **Grid (Just Basics)**
#
# - `display: grid`, `grid-template-columns`
# - `gap`, `place-items`
#
# ### 🔹 6. **Typography**
#
# - `font-size`, `font-weight`, `color`, `line-height`
# - `text-align`, `text-transform`
#
# ### 🔹 7. **Colors & Backgrounds**
#
# - `color`, `background-color`, `rgba`, gradients
# - Hover styles: `:hover`, `:active`, `:focus`
#
# ### 🔹 8. **Sizing & Units**
#
# - `px`, `%`, `em`, `rem`, `vh`, `vw`
# - `width`, `height`, `max-width`
#
# ### 🔹 9. **Borders, Radius, Shadows**
#
# - `border`, `border-radius`
# - `box-shadow`
#
# ### 🔹 10. **Transitions & Animation (Optional)**
#
# - `transition: all 0.3s ease;`
# - `@keyframes`, `animation` (for small UI effects)
