# %% [markdown]
# Sure — here’s a **complete CSS lesson** on the **Box Model**, designed in an easy-to-understand and structured format:
#
# ---
#
# ## 📦 CSS Lesson 2: **The Box Model**
#
# ### 🔑 What is the Box Model?
#
# Every HTML element is treated like a **box**. The **CSS Box Model** explains how these boxes are structured and how spacing is applied inside and around elements.
#
# ### 🔁 Box Model Structure (Outside → In):
#
# ```
# +-----------------------------+
# |         margin              |  ⬅️ Space *outside* the border
# |  +-----------------------+  |
# |  |       border          |  |  ⬅️ Visible outline of the box
# |  |  +-----------------+  |  |
# |  |  |    padding      |  |  |  ⬅️ Space *inside* the box, around content
# |  |  |  +-----------+  |  |  |
# |  |  |  |  content   |  |  |  ⬅️ Actual element text/image
# |  |  |  +-----------+  |  |  |
# |  |  +-----------------+  |  |
# |  +-----------------------+  |
# +-----------------------------+
# ```
#
# ---
#
# ## 🧱 1. **Content**
#
# * This is the **actual stuff** inside the box: text, image, form field, etc.
# * Example:
#
#   ```html
#   <p>Hello World</p>
#   ```
#
# ---
#
# ## 🧢 2. **Padding** (Inside spacing)
#
# * **Padding is the space between the content and the border**.
# * It increases the *inside breathing room* of an element.
# * Example:
#
#   ```css
#   p {
#     padding: 20px;
#   }
#   ```
#
# ---
#
# ## 🧱 3. **Border**
#
# * The **visible edge** surrounding padding and content.
# * You can customize its width, style, and color.
# * Example:
#
#   ```css
#   p {
#     border: 2px solid black;
#   }
#   ```
#
# ---
#
# ## 🌌 4. **Margin** (Outside spacing)
#
# * **Margin is the space between one element and the next**.
# * It creates distance **outside** the border.
# * Example:
#
#   ```css
#   p {
#     margin: 30px;
#   }
#   ```
